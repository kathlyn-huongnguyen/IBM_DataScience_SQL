# %% [markdown]
# ## Libraries and frameworks

# %%
# !pip install ipython-sql
# !pip install pandas

# %%
import pandas as pd 
import sqlite3

# %%
# make if os.path not exist :D 
cnn=sqlite3.connect('chicago.db')

# %%
#census_df=pd.read_csv('ChicagoCensusData.csv').to_sql('census', cnn)

# %%
#schools_df=pd.read_csv('ChicagoPublicSchools.csv').to_sql('schools', cnn)

# %%
#crime_df=pd.read_csv('ChicagoCrimeData.csv').to_sql('crime', cnn)

# %%
# %reload_ext sql

# %%
# %sql sqlite:///chicago.db

# %% [markdown]
# ---

# %% [markdown]
# # QUERIES

# %% [markdown]
# ### <U>CHICAGO CENSUS DATA (2008-2012)<U>

# %% [markdown]
# #### Numbers of community areas

# %%
# %sql SELECT COUNT (COMMUNITY_AREA_NUMBER) FROM CENSUS;
# Out:
#  * sqlite:///chicago.db
# Done.
# [(77,)]

# %%
# %sql SELECT * FROM CENSUS;
# Out:
#  * sqlite:///chicago.db
# Done.
# [(0, 1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (1, 2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0),
#  (2, 3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0),
#  (3, 4.0, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17.0),
#  (4, 5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0),
#  (5, 6.0, 'Lake View', 1.1, 11.4, 4.7, 2.6, 17.0, 60058, 5.0),
#  (6, 7.0, 'Lincoln Park', 0.8, 12.3, 5.1, 3.6, 21.5, 71551, 2.0),
#  (7, 8.0, 'Near North Side', 1.9, 12.9, 7.0, 2.5, 22.6, 88669, 1.0),
#  (8, 9.0, 'Edison Park', 1.1, 3.3, 6.5, 7.4, 35.3, 40959, 8.0),
#  (9, 10.0, 'Norwood Park', 2.0, 5.4, 9.0, 11.5, 39.5, 32875, 21.0),
#  (10, 11.0, 'Jefferson Park', 2.7, 8.6, 12.4, 13.4, 35.5, 27751, 25.0),
#  (11, 12.0, 'Forest Glen', 1.1, 7.5, 6.8, 4.9, 40.5, 44164, 11.0),
#  (12, 13.0, 'North Park', 3.9, 13.2, 9.9, 14.4, 39.0, 26576, 33.0),
#  (13, 14.0, 'Albany Park', 11.3, 19.2, 10.0, 32.9, 32.0, 21323, 53.0),
# ...

# %% [markdown]
# - We are looking into the dataset of 77 community areas, the last row shows the indicators of Chicago

# %% [markdown]
# #### Hardship index ranking

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME, HARDSHIP_INDEX
# FROM CENSUS
# ORDER BY HARDSHIP_INDEX
# DESC;
# Out:
#  * sqlite:///chicago.db
# Done.
# [('Riverdale', 98.0),
#  ('Fuller Park', 97.0),
#  ('South Lawndale', 96.0),
#  ('Englewood', 94.0),
#  ('Gage Park', 93.0),
#  ('West Garfield Park', 92.0),
#  ('New City', 91.0),
#  ('West Englewood', 89.0),
#  ('Washington Park', 88.0),
#  ('North Lawndale', 87.0),
#  ('Humboldt park', 85.0),
#  ('Brighton Park', 84.0),
#  ('East Garfield Park', 83.0),
#  ('Armour Square', 82.0),
#  ('Chicago Lawn', 80.0),
#  ('Burnside', 79.0),
#  ('Oakland', 78.0),
#  ('Lower West Side', 76.0),
#  ('South Chicago', 75.0),
#  ('Auburn Gresham', 74.0),
#  ('Austin', 73.0),
#  ('Hermosa', 71.0),
#  ('Belmont Cragin', 70.0),
#  ('West Elsdon', 69.0),
#  ('Archer Heights', 67.0),
#  ('Greater Grand Crossing', 66.0),
#  ('South Deering', 65.0),
#  ('East Side', 64.0),
#  ('West Pullman', 62.0),
#  ('McKinley Park', 61.0),
#  ('Chatham', 60.0),
#  ('Woodlawn', 58.0),
#  ('Grand Boulevard', 57.0),
#  ('West Lawn', 56.0),
#  ('South Shore', 55.0),
# ...

# %% [markdown]
# - Riverdale has the highest hardship index

# %% [markdown]
# #### Community areas with hardship index >50

# %%
# %%sql
# SELECT COUNT(*) AS 'NUMBER OF COMMUNITY AREAS WITH HARDSHIP INDEX >50'
# FROM CENSUS
# WHERE HARDSHIP_INDEX > 50.0;
# Out:
#  * sqlite:///chicago.db
# Done.
# [(38,)]

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME
# FROM CENSUS
# WHERE HARDSHIP_INDEX > 50.0;
# Out:
#  * sqlite:///chicago.db
# Done.
# [('Albany Park',),
#  ('Belmont Cragin',),
#  ('Hermosa',),
#  ('Humboldt park',),
#  ('Austin',),
#  ('West Garfield Park',),
#  ('East Garfield Park',),
#  ('North Lawndale',),
#  ('South Lawndale',),
#  ('Lower West Side',),
#  ('Armour Square',),
#  ('Oakland',),
#  ('Fuller Park',),
#  ('Grand Boulevard',),
#  ('Washington Park',),
#  ('Woodlawn',),
#  ('South Shore',),
#  ('Chatham',),
#  ('South Chicago',),
#  ('Burnside',),
#  ('Roseland',),
#  ('Pullman',),
#  ('South Deering',),
#  ('East Side',),
#  ('West Pullman',),
#  ('Riverdale',),
#  ('Archer Heights',),
#  ('Brighton Park',),
#  ('McKinley Park',),
#  ('New City',),
#  ('West Elsdon',),
#  ('Gage Park',),
#  ('West Lawn',),
#  ('Chicago Lawn',),
#  ('West Englewood',),
#  ('Englewood',),
#  ('Greater Grand Crossing',),
#  ('Auburn Gresham',)]

# %% [markdown]
# - 38/77 of community areas' hardship_index > 50
# https://www.americashealthrankings.org/explore/annual/measure/EHI/state/ALL

# %% [markdown]
# #### Chicago community areas have per-capita incomes greater than $60,000

# %%
# %%sql
# SELECT COMMUNITY_AREA_NUMBER, COMMUNITY_AREA_NAME, PER_CAPITA_INCOME, HARDSHIP_INDEX
# FROM CENSUS
# WHERE PER_CAPITA_INCOME > 60000
# ORDER BY PER_CAPITA_INCOME DESC;
# Out:
#  * sqlite:///chicago.db
# Done.
# [(8.0, 'Near North Side', 88669, 1.0),
#  (7.0, 'Lincoln Park', 71551, 2.0),
#  (32.0, 'Loop', 65526, 3.0),
#  (6.0, 'Lake View', 60058, 5.0)]

# %%
# %%sql
# SELECT COMMUNITY_AREA_NUMBER, COMMUNITY_AREA_NAME, PER_CAPITA_INCOME, HARDSHIP_INDEX
# FROM CENSUS
# ORDER BY PER_CAPITA_INCOME
# DESC;
# Out:
#  * sqlite:///chicago.db
# Done.
# [(8.0, 'Near North Side', 88669, 1.0),
#  (7.0, 'Lincoln Park', 71551, 2.0),
#  (32.0, 'Loop', 65526, 3.0),
#  (6.0, 'Lake View', 60058, 5.0),
#  (33.0, 'Near South Side', 59077, 7.0),
#  (5.0, 'North Center', 57123, 6.0),
#  (28.0, 'Near West Side', 44689, 15.0),
#  (12.0, 'Forest Glen', 44164, 11.0),
#  (24.0, 'West Town', 43198, 10.0),
#  (9.0, 'Edison Park', 40959, 8.0),
#  (72.0, 'Beverly', 39523, 12.0),
#  (41.0, 'Hyde Park', 39056, 14.0),
#  (4.0, 'Lincoln Square', 37524, 17.0),
#  (39.0, 'Kenwood', 35911, 26.0),
#  (3.0, 'Uptown', 35787, 20.0),
#  (74.0, 'Mount Greenwood', 34381, 16.0),
#  (77.0, 'Edgewater', 33385, 19.0),
#  (10.0, 'Norwood Park', 32875, 21.0),
#  (22.0, 'Logan Square', 31908, 23.0),
#  (48.0, 'Calumet Heights', 28887, 38.0),
#  (None, 'CHICAGO', 28202, None),
#  (11.0, 'Jefferson Park', 27751, 25.0),
#  (16.0, 'Irving Park', 27249, 34.0),
#  (75.0, 'Morgan Park', 27149, 30.0),
#  (13.0, 'North Park', 26576, 33.0),
# ...

# %% [markdown]
# - %of index>50 among high income is lower than those of low income communities

# %% [markdown]
# #### Community areas with per capita income less than 11000

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME, PER_CAPITA_INCOME
# FROM CENSUS
# WHERE PER_CAPITA_INCOME < 11000;
# Out:
#  * sqlite:///chicago.db
# Done.
# [('West Garfield Park', 10934),
#  ('South Lawndale', 10402),
#  ('Fuller Park', 10432),
#  ('Riverdale', 8201)]

# %% [markdown]
# #### 5 community areas with highest % of households below poverty line.

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME, PERCENT_HOUSEHOLDS_BELOW_POVERTY
# FROM CENSUS
# ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY
# DESC
# LIMIT 5;
# Out:
#  * sqlite:///chicago.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %% [markdown]
# ---

# %% [markdown]
# ### <U>CHICAGO PUBLIC SCHOOLS DATA (2008-2012)<U>

# %%
# %sql SELECT COUNT(SCHOOL_ID) AS ROWS FROM SCHOOLS;
# Out:
#  * sqlite:///chicago.db
# Done.
# [(566,)]

# %% [markdown]
# #### Number of Elementary Schools

# %%
# %%sql
# SELECT COUNT(*)
# FROM SCHOOLS
# WHERE "Elementary, Middle, or High School" = "ES";
# Out:
#  * sqlite:///chicago.db
# Done.
# [(462,)]

# %% [markdown]
# #### Schools with the highes safety score

# %%
# %sql select MAX(Safety_Score) AS MAX_SAFETY_SCORE from SCHOOLS
# Out:
#  * sqlite:///chicago.db
# Done.
# [(99.0,)]

# %%
# %sql select Name_of_School, Safety_Score from SCHOOLS where \
  Safety_Score= (select MAX(Safety_Score) from SCHOOLS)
# Out:
#  * sqlite:///chicago.db
# Done.
# [('Abraham Lincoln Elementary School', 99.0),
#  ('Alexander Graham Bell Elementary School', 99.0),
#  ('Annie Keller Elementary Gifted Magnet School', 99.0),
#  ('Augustus H Burley Elementary School', 99.0),
#  ('Edgar Allan Poe Elementary Classical School', 99.0),
#  ('Edgebrook Elementary School', 99.0),
#  ('Ellen Mitchell Elementary School', 99.0),
#  ('James E McDade Elementary Classical School', 99.0),
#  ('James G Blaine Elementary School', 99.0),
#  ('LaSalle Elementary Language Academy', 99.0),
#  ('Mary E Courtenay Elementary Language Arts Center', 99.0),
#  ('Northside College Preparatory High School', 99.0),
#  ('Northside Learning Center High School', 99.0),
#  ('Norwood Park Elementary School', 99.0),
#  ('Oriole Park Elementary School', 99.0),
#  ('Sauganash Elementary School', 99.0),
#  ('Stephen Decatur Classical Elementary School', 99.0),
#  ('Talman Elementary School', 99.0),
#  ('Wildwood Elementary School', 99.0)]

# %% [markdown]
# #### What are the top 10 schools with the highest "Average Student Attendance"?¶

# %%
# %%sql
# SELECT NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE
# FROM SCHOOLS
# ORDER BY AVERAGE_STUDENT_ATTENDANCE
# DESC
# LIMIT 10;
# Out:
#  * sqlite:///chicago.db
# Done.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %% [markdown]
# #### Retrieve the list of 5 Schools with the lowest Average Student Attendance sorted in ascending order based on attendance

# %%
# %%sql
# SELECT NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE
# FROM SCHOOLS
# WHERE AVERAGE_STUDENT_ATTENDANCE IS NOT NULL
# ORDER BY AVERAGE_STUDENT_ATTENDANCE
# LIMIT 5;
# Out:
#  * sqlite:///chicago.db
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %% [markdown]
# #### Schools have Average Student Attendance lower than 70%

# %%
# %%sql
# SELECT NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE
# FROM SCHOOLS
# WHERE AVERAGE_STUDENT_ATTENDANCE < 70;
# Out:
#  * sqlite:///chicago.db
# Done.
# [('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Dyett High School', '62.50%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Roberto Clemente Community Academy High School', '69.60%'),
#  ('Wendell Phillips Academy High School', '63.00%')]

# %% [markdown]
# #### Total College Enrollment for each Community Area

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME, SUM(COLLEGE_ENROLLMENT) AS TOTAL_ENROLLMENT
# FROM SCHOOLS
# GROUP BY COMMUNITY_AREA_NAME
# ORDER BY SUM(COLLEGE_ENROLLMENT)
# DESC;
# Out:
#  * sqlite:///chicago.db
# Done.
# [('SOUTH LAWNDALE', 14793),
#  ('BELMONT CRAGIN', 14386),
#  ('AUSTIN', 10933),
#  ('GAGE PARK', 9915),
#  ('BRIGHTON PARK', 9647),
#  ('WEST TOWN', 9429),
#  ('HUMBOLDT PARK', 8620),
#  ('WEST RIDGE', 8197),
#  ('NEAR WEST SIDE', 7975),
#  ('NEW CITY', 7922),
#  ('IRVING PARK', 7764),
#  ('NORTH CENTER', 7541),
#  ('LOGAN SQUARE', 7351),
#  ('LOWER WEST SIDE', 7257),
#  ('CHICAGO LAWN', 7086),
#  ('LAKE VIEW', 7055),
#  ('ROSELAND', 7020),
#  ('PORTAGE PARK', 6954),
#  ('ALBANY PARK', 6864),
#  ('ENGLEWOOD', 6832),
#  ('ASHBURN', 6483),
#  ('NORWOOD PARK', 6469),
#  ('WEST ENGLEWOOD', 5946),
#  ('LINCOLN PARK', 5615),
#  ('EAST GARFIELD PARK', 5337),
#  ('EAST SIDE', 5305),
#  ('NORTH LAWNDALE', 5146),
#  ('CHATHAM', 5042),
#  ('ARCHER HEIGHTS', 4823),
#  ('DOUGLAS', 4670),
#  ('EDGEWATER', 4600),
#  ('DUNNING', 4568),
#  ('GARFIELD RIDGE', 4552),
#  ('SOUTH SHORE', 4543),
#  ('UPTOWN', 4388),
#  ('KENWOOD', 4287),
#  ('NORTH PARK', 4210),
# ...

# %% [markdown]
# #### 5 Community Areas with the least total College Enrollment

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME, SUM(COLLEGE_ENROLLMENT) AS TOTAL_ENROLLMENT
# FROM SCHOOLS
# GROUP BY COMMUNITY_AREA_NAME
# ORDER BY TOTAL_ENROLLMENT
# LIMIT 5;
# Out:
#  * sqlite:///chicago.db
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871)]

# %% [markdown]
# #### List 5 schools with lowest safety score.

# %%
# %sql select MIN(Safety_Score) AS MIN_SAFETY_SCORE from SCHOOLS
# Out:
#  * sqlite:///chicago.db
# Done.
# [(1.0,)]

# %%
# %%sql
# SELECT SCHOOL_ID, SAFETY_SCORE
# FROM SCHOOLS
# WHERE SAFETY_SCORE IS NOT NULL
# ORDER BY SAFETY_SCORE
# LIMIT 5;
# Out:
#  * sqlite:///chicago.db
# Done.
# [(609819, 1.0), (610108, 5.0), (610202, 6.0), (609927, 11.0), (609712, 13.0)]

# %% [markdown]
# #### The average safety score for all types of schools.

# %%
# %%sql
# SELECT "Elementary, Middle, or High School", AVG(SAFETY_SCORE)
# FROM SCHOOLS
# GROUP BY "Elementary, Middle, or High School";
# Out:
#  * sqlite:///chicago.db
# Done.
# [('ES', 49.52038369304557), ('HS', 49.62352941176471), ('MS', 48.0)]

# %% [markdown]
# #### The hardship index for the community area which has College Enrollment of 4368

# %%
# %%sql
# select hardship_index
# from CENSUS CS, SCHOOLS S
# where CS.community_area_number = S.community_area_number
# and college_enrollment = 4368
# Out:
#  * sqlite:///chicago.db
# Done.
# [(6.0,)]

# %% [markdown]
# #### The hardship index for the community area which has the school with the highest enrollment.

# %%
# %%sql
# select community_area_number, community_area_name, hardship_index
# from CENSUS
# where community_area_number in
# (select community_area_number
# from schools order by college_enrollment desc limit 1);
# Out:
#  * sqlite:///chicago.db
# Done.
# [(5.0, 'North Center', 6.0)]

# %% [markdown]
# ---

# %% [markdown]
# ### <U>CHICAGO CRIME DATA (2008-2012)<U>

# %% [markdown]
# Problem 1: Find the total number of crimes recorded in the CRIME table.

# %%
# %sql SELECT COUNT(ID) FROM CRIME;
# Out:
#  * sqlite:///chicago.db
# Done.
# [(533,)]

# %% [markdown]
# #### Case numbers for crimes involving minors?

# %%
# %%sql
# SELECT CASE_NUMBER, DESCRIPTION
# FROM CRIME
# WHERE DESCRIPTION LIKE "%MINOR%"
# Out:
#  * sqlite:///chicago.db
# Done.
# [('HL266884', 'SELL/GIVE/DEL LIQUOR TO MINOR'),
#  ('HK238408', 'ILLEGAL CONSUMPTION BY MINOR')]

# %% [markdown]
# #### Kidnapping crimes involving a child ( children are not considered minors for the purposes of crime analysis)

# %%
# %%sql
# SELECT CASE_NUMBER, PRIMARY_TYPE, DESCRIPTION
# FROM CRIME
# WHERE PRIMARY_TYPE LIKE "%KIDNAP%" AND DESCRIPTION LIKE "%CHILD%"
# Out:
#  * sqlite:///chicago.db
# Done.
# [('HN144152', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER')]

# %% [markdown]
# #### Crimes were recorded at schools?

# %%
# %%sql
# SELECT DISTINCT(PRIMARY_TYPE)
# FROM CRIME
# WHERE LOCATION_DESCRIPTION LIKE "%SCHOOL%"
# Out:
#  * sqlite:///chicago.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %% [markdown]
# #### Community area with most crime prone?

# %%
# %%sql
# SELECT COMMUNITY_AREA_NUMBER,
# COUNT(CASE_NUMBER) AS NUMBER_OF_CASES
# FROM CRIME
# GROUP BY COMMUNITY_AREA_NUMBER
# ORDER BY NUMBER_OF_CASES
# DESC
# LIMIT 1;
# Out:
#  * sqlite:///chicago.db
# Done.
# [(25.0, 43)]

# %%
# %%sql
# SELECT COMMUNITY_AREA_NUMBER, COMMUNITY_AREA_NAME
# FROM CENSUS
# WHERE COMMUNITY_AREA_NUMBER = 25;
# Out:
#  * sqlite:///chicago.db
# Done.
# [(25.0, 'Austin')]

# %% [markdown]
# #### Name of the community area with highest hardship index.

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME, HARDSHIP_INDEX
# FROM CENSUS
# WHERE HARDSHIP_INDEX=(SELECT MAX(HARDSHIP_INDEX) FROM CENSUS)
# Out:
#  * sqlite:///chicago.db
# Done.
# [('Riverdale', 98.0)]

# %% [markdown]
# #### The Community Area Name with most number of crimes?

# %%
# %%sql
# SELECT COMMUNITY_AREA_NUMBER, COMMUNITY_AREA_NAME
# FROM CENSUS
# WHERE COMMUNITY_AREA_NUMBER=
# (SELECT COMMUNITY_AREA_NUMBER FROM CRIME
# GROUP BY COMMUNITY_AREA_NUMBER
# ORDER BY COUNT (COMMUNITY_AREA_NUMBER) DESC LIMIT 1)
# Out:
#  * sqlite:///chicago.db
# Done.
# [(25.0, 'Austin')]

# %% [markdown]
# ---

# %% [markdown]
# ##  Relationship between the census, school, crime data in the Chicago

# %% [markdown]
# #### School Average Attendance of communities with a hardship index of 98

# %%
# %%sql
# SELECT CS.HARDSHIP_INDEX,
# S.NAME_OF_SCHOOL, S.COMMUNITY_AREA_NAME, S.AVERAGE_STUDENT_ATTENDANCE
# FROM CENSUS CS LEFT JOIN SCHOOLS S
# ON CS.COMMUNITY_AREA_NUMBER = CS.COMMUNITY_AREA_NUMBER
# WHERE CS.HARDSHIP_INDEX=98;
# Out:
#  * sqlite:///chicago.db
# Done.
# [(98.0, 'Abraham Lincoln Elementary School', 'LINCOLN PARK', '96.00%'),
#  (98.0, 'Adam Clayton Powell Paideia Community Academy Elementary School', 'SOUTH SHORE', '95.60%'),
#  (98.0, 'Adlai E Stevenson Elementary School', 'ASHBURN', '95.70%'),
#  (98.0, 'Agustin Lara Elementary Academy', 'NEW CITY', '95.50%'),
#  (98.0, 'Air Force Academy High School', 'ARMOUR SQUARE', '93.30%'),
#  (98.0, 'Albany Park Multicultural Academy', 'ALBANY PARK', '97.00%'),
#  (98.0, 'Albert G Lane Technical High School', 'NORTH CENTER', '96.30%'),
#  (98.0, 'Albert R Sabin Elementary Magnet School', 'WEST TOWN', '94.70%'),
#  (98.0, 'Alcott High School for the Humanities', 'NORTH CENTER', '92.70%'),
#  (98.0, 'Alessandro Volta Elementary School', 'ALBANY PARK', '96.40%'),
#  (98.0, 'Alexander Graham Bell Elementary School', 'NORTH CENTER', '96.30%'),
#  (98.0, 'Alexander Graham Elementary School', 'NEW CITY', '92.50%'),
# ...

# %% [markdown]
# #### Crimes that took place at a school. Include case number, crime type and community name.

# %%
# %%sql
# SELECT CS.COMMUNITY_AREA_NAME,
# CR.CASE_NUMBER, CR.PRIMARY_TYPE, CR.LOCATION_DESCRIPTION
# FROM CENSUS CS LEFT JOIN CRIME CR
# ON CS.COMMUNITY_AREA_NUMBER = CR.COMMUNITY_AREA_NUMBER
# WHERE CR.LOCATION_DESCRIPTION LIKE '%SCHOOL%';
# Out:
#  * sqlite:///chicago.db
# Done.
# [('Rogers Park', 'HK577020', 'NARCOTICS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('Lincoln Square', 'HL725506', 'BATTERY', 'SCHOOL, PUBLIC, BUILDING'),
#  ('Austin', 'HH639427', 'BATTERY', 'SCHOOL, PUBLIC, BUILDING'),
#  ('Austin', 'HS200939', 'CRIMINAL DAMAGE', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('East Garfield Park', 'HT315369', 'ASSAULT', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('Douglas', 'HP716225', 'BATTERY', 'SCHOOL, PUBLIC, BUILDING'),
#  ('South Shore', 'HL353697', 'BATTERY', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('Brighton Park', 'HS305355', 'NARCOTICS', 'SCHOOL, PUBLIC, BUILDING'),
#  ('Ashburn', 'HR585012', 'CRIMINAL TRESPASS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('Ashburn', 'JA460432', 'BATTERY', 'SCHOOL, PUBLIC, GROUNDS')]

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# #### For privacy reasons, creating a view that only enables users to select just the school name and the icon fields from the CHICAGO_PUBLIC_SCHOOLS table. Therefore, we can ensure that users cannot see the actual scores given to a school, just the icon associated with their score

# %%
# %%sql
# CREATE VIEW SCHOOLS_INFO (SCHOOL_NAME, SAFETY_RATING, FAMILY_RATING,
#                           ENVIRONMENT_RATING, INSTRUCTION_RATING, LEADERS_RATING,
#                           TEACHERS_RATING)
# AS SELECT NAME_OF_SCHOOL, SAFETY_ICON, FAMILY_INVOLVEMENT_ICON, ENVIRONMENT_ICON,
# INSTRUCTION_ICON, LEADERS_ICON, TEACHERS_ICON
# FROM SCHOOLS;
# Out:
#  * sqlite:///chicago.db
# Done.
# []

# %%
# %sql SELECT * FROM SCHOOLS_INFO;
# Out:
#  * sqlite:///chicago.db
# Done.
# [('Abraham Lincoln Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('Adam Clayton Powell Paideia Community Academy Elementary School', 'Average', 'Strong', 'Strong', 'Very Strong', 'Weak', 'Strong'),
#  ('Adlai E Stevenson Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Agustin Lara Elementary Academy', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Air Force Academy High School', 'Average', 'Strong', 'Strong', 'Average', 'Weak', 'Average'),
#  ('Albany Park Multicultural Academy', 'Strong', 'Weak', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Albert G Lane Technical High School', 'Very Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Albert R Sabin Elementary Magnet School', 'Strong', 'NDA', 'Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Alcott High School for the Humanities', 'Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
# ...

# %% [markdown]
# - Test:

# %%
# %sql SELECT SCHOOL_NAME, LEADERS_RATING FROM SCHOOLS_INFO;
# Out:
#  * sqlite:///chicago.db
# Done.
# [('Abraham Lincoln Elementary School', 'Weak'),
#  ('Adam Clayton Powell Paideia Community Academy Elementary School', 'Weak'),
#  ('Adlai E Stevenson Elementary School', 'Weak'),
#  ('Agustin Lara Elementary Academy', 'Weak'),
#  ('Air Force Academy High School', 'Weak'),
#  ('Albany Park Multicultural Academy', 'Weak'),
#  ('Albert G Lane Technical High School', 'Weak'),
#  ('Albert R Sabin Elementary Magnet School', 'Weak'),
#  ('Alcott High School for the Humanities', 'Weak'),
#  ('Alessandro Volta Elementary School', 'Weak'),
#  ('Alexander Graham Bell Elementary School', 'Weak'),
#  ('Alexander Graham Elementary School', 'Weak'),
#  ('Alexander Hamilton Elementary School', 'Weak'),
#  ('Alexander von Humboldt Elementary School', 'Weak'),
#  ('Alex Haley Elementary Academy', 'Weak'),
#  ('Alfred David Kohn Elementary School', 'Weak'),
#  ('Alfred Nobel Elementary School', 'Weak'),
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### Create a store procedure to update leader's score field and leader's icon field when a score field is updates.  Transactions is used for rollback  purpose when input for leaders_score is outside the allowed range (0-99)
# - SQLLITE does not support store procedure queries

# %% [markdown]
# DELIMITER //
# CREATE PROCEDURE UPDATE_LEADERS_SCORE (IN IN_SCHOOL_IN INT, IN IN_LEADERS_SCORE INT)
# BEGIN
# 	START TRANSACTION;
#     UPDATE SCHOOLS
#     SET LEADERS_SCORE = IN_LEADERS_SCORE
#     WHERE SCHOOL_ID = IN_SCHOOL_ID;
#     IF IN_LEADERS_SCORE > 0 AND IN_LEADERS_SCORE <20 THEN UPDATE SCHOOLS SET LEADERS_ICON = 'VERY WEAK';
# 	ELSEIF IN_LEADERS_SCORE < 40 THEN UPDATE SCHOOLS SET LEADERS_ICON = 'WEAK'  WHERE SCHOOL_ID = IN_SCHOOL_ID;
# 	ELSEIF IN_LEADERS_SCORE < 60 THEN UPDATE SCHOOLS SET LEADERS_ICON = 'AVERAGE'  WHERE SCHOOL_ID = IN_SCHOOL_ID;
# 	ELSEIF IN_LEADERS_SCORE < 80 THEN UPDATE SCHOOLS SET LEADERS_ICON = 'STRONG'  WHERE SCHOOL_ID = IN_SCHOOL_ID;
# 	ELSEIF IN_LEADERS_SCORE < 100 THEN UPDATE SCHOOLS SET LEADERS_ICON = 'VERY STRONG'  WHERE SCHOOL_ID = IN_SCHOOL_ID;
# 	ELSEIF IN_LEADERS_SCORE >= 100 THEN ROLLBACK WORK;
#     COMMIT;
#     END IF;
# END //
